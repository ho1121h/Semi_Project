# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("스팀목록10개_리뷰.csv")
data
# Out:
#      gameid                                             review  steam_purchase
# 0    960170                   호랑이는 죽어서 가죽을 남기고 요구르팅은 죽어서 를 남겼다            True
# 1    960170  저는 오른팔에 장애가 있어서 한손으로 하는 사람입니다 남은 한 손도 완전하지가 않죠...            True
# 2    960170  가지만 생각하지말자 여기만 넘으면 맥스콤보다 내가 어떻게 치고있지 내가 눈을 언제 ...            True
# 3    960170                                      시간해도 여전히 뉴비인겜            True
# 4    960170  나 리듬게임에 소질 있는거같다 라고 생각하시는 여러분들은 래더매치를 돌리는 순간 강...            True
# ..      ...                                                ...             ...
# 975  374320  누군가에겐 최악 누군가에겐 잊지 못할 추억을 선사한 최고의 게임 언제나 누구에게나 ...            True
# 976  374320                                     잠깐 해봤는데 할만 하네요            True
# 977  374320  찐따들만 주구장창 쳐모인게임으로 바뀜 핵새끼들 지들이 못하니까 핵으로 무쌍질하면서 ...            True
# 978  374320                                           미야자키 대머리            True
# 979  374320  조작법을 익혀 나가면서 맞는 타이밍에 구르기가 성공하거나 패링해서 반격할 때의 쾌감...            True
#
# [980 rows x 3 columns]

# %%
data = data.replace(960170,"DJMAX")
data = data.replace(1144200,"Ready_or_Not")
data = data.replace(601150,"Devil_May_Cry_5")
data = data.replace(1635450,"Longvinter")
data = data.replace(1593500,"God_of_War")
data = data.replace(1245620,"ELDEN_RING")
data = data.replace(582010,"Monster_Hunter_World")
data = data.replace(892970,"Valheim")
data = data.replace(1506830,"FIFA_22")
data = data.replace(374320,"DARK_SOULS_III")
'''
data['game_name'] = np.where(data.gameid == 960170,"DJMAX",
                    np.where(data.gameid ==1144200,"Ready_or_Not",
                    np.where(data.gameid ==601150,"Devil_May_Cry_5",
                    np.where(data.gameid ==1635450,"Longvinter",
                    np.where(data.gameid==1593500,"God_of_War",
                    np.where(data.gameid==1245620,"ELDEN_RING",
                    np.where(data.gameid==582010,"Monster_Hunter_World",
                    np.where(data.gameid==892970,"Valheim",
                    np.where(data.gameid==1506830,"FIFA_22",
                    np.where(data.gameid==374320,"DARK_SOULS_III"))))))))))'''

data
# Out:
#              gameid                                             review  \
# 0             DJMAX                   호랑이는 죽어서 가죽을 남기고 요구르팅은 죽어서 를 남겼다
# 1             DJMAX  저는 오른팔에 장애가 있어서 한손으로 하는 사람입니다 남은 한 손도 완전하지가 않죠...
# 2             DJMAX  가지만 생각하지말자 여기만 넘으면 맥스콤보다 내가 어떻게 치고있지 내가 눈을 언제 ...
# 3             DJMAX                                      시간해도 여전히 뉴비인겜
# 4             DJMAX  나 리듬게임에 소질 있는거같다 라고 생각하시는 여러분들은 래더매치를 돌리는 순간 강...
# ..              ...                                                ...
# 975  DARK_SOULS_III  누군가에겐 최악 누군가에겐 잊지 못할 추억을 선사한 최고의 게임 언제나 누구에게나 ...
# 976  DARK_SOULS_III                                     잠깐 해봤는데 할만 하네요
# 977  DARK_SOULS_III  찐따들만 주구장창 쳐모인게임으로 바뀜 핵새끼들 지들이 못하니까 핵으로 무쌍질하면서 ...
# 978  DARK_SOULS_III                                           미야자키 대머리
# 979  DARK_SOULS_III  조작법을 익혀 나가면서 맞는 타이밍에 구르기가 성공하거나 패링해서 반격할 때의 쾌감...
#
#      steam_purchase
# 0              True
# 1              True
# 2              True
# 3              True
# ...

# %%
data.to_csv('리뷰.csv', index=False)
